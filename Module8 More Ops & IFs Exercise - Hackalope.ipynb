# %% [markdown]
# ### Exercise 1
# Ask for an exam score and store that number. If the number is greater than 100, then print out 'You cannot have an exam score higher than 100'. If the number doesn't exceeed 100 but is greater than or equal to 75, then print out 'You did great on your exam!'. Otherwise if they scored lower than 75, then print out 'You need to study harder'.

# %%
score = int(input("Submit an exam score : "))

if score > 100:
  print("You cannot have a score higher than 100") # cheated
elif score >= 75:
  print("You did great on your exam") # cheated, but in a smart way
else:
  print("You need to study harder") # slacker
# Out:
# Submit an exam score : 83
# You did great on your exam

# %% [markdown]
# ### Exercise 2
# Ask a user to enter two numbers and find their average. Then, print out the average and whether each number is below or above average. Determine if a function should be created or not.

# %%
def above_below(num, avg):
  if num > avg:
    return("above")
  else:
    return("below")

# %%
foo = int(input("Enter number : "))
bar = int(input("Enter number : "))

avg = (foo + bar) / 2
# Out:
# Enter number : 16
# Enter number : 83

# %%
print('The average is {:,.2f}.\nThe number {} is {} the average.\nThe number {} is {} the average.'.format(avg, foo, above_below(foo, avg), bar, above_below(bar, avg)))
# Out:
# The average is 49.50.
# The number 16 is below the average.
# The number 83 is above the average.

# %% [markdown]
# ### Exercise 3
# Write a function to convert a test score to a grade where
#  - 90 - 100: A
#  - 80 - 89:  B
#  - 70 - 79:  C
#  - 60 - 69:  D
#  - < 60   :  F
#
# If a score is not between 0 and 100 then print out an error message. In the program, ask the user for a score and then call your function.

# %%
def score_grade(score):
  if score > 100:
    return("Error")
  elif score >= 90:
    return("A")
  elif score >= 80:
    return("B")
  elif score >= 70:
    return("C")
  elif score >= 60:
    return("D")
  elif score < 60 and score >= 0:
    return("F")
  else:
    return("Error")

# %%
score = int(input("Submit score : "))

print(score_grade(score))
# Out:
# Submit score : 45
# F

# %% [markdown]
# ### Exercise 4
# Convert following decimal number to a binary number by hand:
#
#     61
#     15
#     71

# %%
# 111101
# 1111
# 1000111

# %% [markdown]
# ### Exercise 5
# When a = 61 and b = 15, what is the result of following bitwise opertion? Use inline comments to show your result in a binary number. Find your answer by hand.
#
#     a & b
#     a | b
#     a ^ b
#     a >> 2

# %%
a = 61 # 11011
b = 15 # 01111

print('the and (&) operation is {} and is bin {:b}'.format(a & b, a & b))               # 01011
print('the or (|) operation is {} and is bin {:b}'.format(a | b, a | b))                # 11111
print('the xor (^) operation is {} and is bin {:b}'.format(a ^ b, a ^ b))               # 10100
print('the shift a by 2 (>> 2) operation is {} and is bin {:b}'.format(a >> 2, a >> 2)) # 1111
# Out:
# the and (&) operation is 13 and is bin 1101
# the or (|) operation is 63 and is bin 111111
# the xor (^) operation is 50 and is bin 110010
# the shift a by 2 (>> 2) operation is 15 and is bin 1111
