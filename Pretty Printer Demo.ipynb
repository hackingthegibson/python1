# %%
import requests
import json
import pprint
pp = pprint.PrettyPrinter(indent=2)
show = pp.pprint

url = 'https://api.hackingthegibson.online/episode'

response = requests.get(url).json()
ep_data = json.loads(response)

print(response)
print(ep_data)
show(ep_data)
# Out:
# {"season": "7", "media": {"duration": "2654", "link": "https://hacking-the-gibson-podcast.s3.amazonaws.com/HtG_S07_E12_Firewalls_Part1.mp3", "file": "HtG_S07_E12_Firewalls_Part1.mp3", "size": "31841437"}, "episode": "12", "titletext": "Season 7 Episode 12 - Firewalls, Part 1", "presenter": "Hackalope", "season_name": "Season 7", "latest": true, "notes": "Whether you\u2019re working in cybersecurity or acting as your own tech support at home, you\u2019ve probably heard about firewalls. A properly configured firewall acts like a fastidious border guard, making all the little data packets show their credentials before they can enter the country - er, the computer. In this episode, we\u2019ll learn about the history of firewalls (including where that name came from), how they work, and how they\u2019ve adapted from the days of big hair to the era of big data.", "publish": 1698019200, "references": [{"refTitle": "Univ New Mexico - History and Survey of Network Firewalls", "refUrl": "https
# ...
