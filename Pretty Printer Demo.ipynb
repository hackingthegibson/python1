# %%
import requests
import json
import pprint
pp = pprint.PrettyPrinter(indent=2)
show = pp.pprint

url = 'https://api.hackingthegibson.online/episode'

ep_data = json.loads(requests.get(url).json())

show(ep_data)
# Out:
# { 'description': 'Keeping The Magic Smoke Inside Your Computer Since 1988',
#   'episode': '12',
#   'id': 93,
#   'latest': True,
#   'media': { 'duration': '2654',
#              'file': 'HtG_S07_E12_Firewalls_Part1.mp3',
#              'link': 'https://hacking-the-gibson-podcast.s3.amazonaws.com/HtG_S07_E12_Firewalls_Part1.mp3',
#              'size': '31841437'},
#   'notes': 'Whether you’re working in cybersecurity or acting as your own tech '
#            'support at home, you’ve probably heard about firewalls. A properly '
#            'configured firewall acts like a fastidious border guard, making '
#            'all the little data packets show their credentials before they can '
#            'enter the country - er, the computer. In this episode, we’ll learn '
#            'about the history of firewalls (including where that name came '
#            'from), how they work, and how they’ve adapted from the days of big '
#            'hair to the era of big data.',
# ...
