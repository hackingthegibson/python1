# %% [markdown]
# 1. Print cookies and milk are a great dessert.

# %%
print("cookies and milk are a great dessert.")
# Out:
# cookies and milk are a great dessert.

# %% [markdown]
# 2. Print out your favorite color and above the code, comment what you are doing.

# %%
# Just a print statement with 2 declared strings
print('cyan','print("cookies and milk are a great dessert.")')
# Out:
# cyan print("cookies and milk are a great dessert.")

# %% [markdown]
# 3. Print out your favority color again and add an in-line comment.

# %%
print('cyan') # oh look an inline comment

# %% [markdown]
# 4. Print the sumation of numbers 1 to 10

# %%
sum = int()
for i in range(1,11):
    sum+=i
print(sum)
# Out:
# 55

# %% [markdown]
# 5. Print what 6 to the 7th power is.

# %%
print(f"{6**7}")
# Out:
# 279936

# %% [markdown]
# 6. Print the remainder of 100 divided by 11.

# %%
print(f"{100%11}")
# Out:
# 1

# %% [markdown]
# 7. What is the result of "Python" + "1"

# %%
print("Python"+"1")
# Out:
# Python1

# %% [markdown]
# 8. Print out 100 divided by 5

# %%
print(f"{100/5}")
# Out:
# 20.0

# %% [markdown]
# 9. What is the difference between 10/4 and 10//4?  Print out the result

# %%
print(f"{10/4 - 10//4}")
# Out:
# 0.5

# %% [markdown]
# 10. Create a variable named foo that stores a string value.

# %%
foo  = input("Give a sting value : ")
# Out:
# Give a sting value : Bar

# %% [markdown]
# 11. Print foo variable

# %%
print(foo)
# Out:
# Bar

# %% [markdown]
# 12. Create a variable called height and store your height value there.
# Print a sentence describing your height and use the variable in the sentence as well.

# %%
height = int()
height = 100

print(f'Is the President over {height} feet tall?\nNo comment!')
# Out:
# Is the President over 100 feet tall?
# No comment!

# %% [markdown]
# 13. Concate two strings together using variables and print out the result

# %%
metasyntatic1 = "foo"
metasyntatic2 = "bar"
metasyntatic3 = "baz"

print(metasyntatic1+metasyntatic2+metasyntatic3)
# Out:
# foobarbaz

# %% [markdown]
# 14. Use the two different quotes in a string and print out the sentence

# %%
death_sentence = 'When I read the instructions I exclaimed \"What are they asking for?\".'

print(death_sentence)
# Out:
# When I read the instructions I exclaimed "What are they asking for?".

# %% [markdown]
# 15. Print out Hello World! 7 times each on a new line using only one line of code.

# %%
print("Hello World!\n"*7)
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!

# %% [markdown]
# 16. What is the result of "apple" > "Apple"

# %%
foo = "apple" > "Apple"

print(foo)
# Out:
# True

# %% [markdown]
# 17. Print out if 25 multiplied by 54 is bigger than 33 multipled by 33

# %%
if 25*54 > 33**2:
  print("out")
# Out:
# out

# %% [markdown]
# 18. What is the result of of 123 == “123”?

# %%
foo = 123 == "123"

print(foo)
# Out:
# False

# %% [markdown]
# 19. Ask a user for width and length of a rectangle. Then compute its area and perimeter.

# %%
length = input("length of the rectangle : ")
width = input("width of the rectangle : ")

print(f"perimeter : {int(length)*2+int(width)*2}")
# Out:
# length of the rectangle : 20
# width of the rectangle : 15
# perimeter : 70

# %% [markdown]
# 20. Ask a user for two whole numbers. Then compute their sum and difference.

# %%
demand_num1 = input("Give me a number or the dog gets it : ")
demand_num2 = input("Give me a number or the cat gets it : ")

print(f'Sum is {int(demand_num1)+int(demand_num2)}\nDifference is {abs(int(demand_num1)-int(demand_num2))}')
# Out:
# Give me a number or the dog gets it : 4
# Give me a number or the cat gets it : 6
# Sum is 10
# Difference is 2
